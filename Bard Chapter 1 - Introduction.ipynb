# %% [markdown]
# # Chapter 1 - Introduction
# * Requirements - ipywidgets, bokeh, numpy

# %% [markdown]
# ### Double Layer Capacitance

# %%
from ipywidgets import interact
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import gridplot
from bokeh.plotting import figure
output_notebook()

x = np.linspace(0, 60, 200)
E = 0.5
y = x*E*1/x
# Rs in Ohms
# Cd in uF
Rs=1
Cd=20
y2 = E/Rs*np.exp(-x/(Rs*Cd))

p = figure(title="Applied E", plot_height=300, plot_width=600, y_range=(-3,3))
pp = figure(title="Resultant i", plot_height=300, plot_width=600, x_range = p.x_range, y_range=p.y_range)
r = p.line(x, y, color="#2222aa", line_width=3)
rr = pp.line(x, y2, color="#2222aa", line_width=3)

def update(f, E=0.1, Rs=1, Cd=20):
    if   f == "step": 
        r.data_source.data['y'] = x*E*1/x
        rr.data_source.data['y'] = E/Rs*np.exp(-x/(Rs*Cd))
    elif f == "ramp":
        r.data_source.data['y'] = (E*x)/max(x)
        v=E/max(x)
        rr.data_source.data['y'] = v*Cd*(1-np.exp(-x/(Rs*Cd)))
    elif f == "triangle":
        r.data_source.data['y'] = np.concatenate((np.array((2*E*x)/max(x))[0:len(x)/2-1],np.array(2*E-(2*E*x)/max(x))[len(x)/2:len(x)-1]),axis=0)
        v=E/max(x)
        rr.data_source.data['y'] = np.concatenate((np.array(v*Cd*(1-np.exp(-x/(Rs*Cd))))[0:len(x)/2-1],np.array(-v*Cd*(1-np.exp(-x/(Rs*Cd))))[0:len(x)/2-1]),axis=0)
    push_notebook()
    
s = gridplot([[p],[pp]], toolbar_location=None)
show(s, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f8f9cbdf-6d79-4924-aa39-62581858009f">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="3fa1d0e5-a59d-4a40-ba88-87dff8acc7b7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#3fa1d0e5-a59d-4a40-ba88-87dff8acc7b7").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("d6f8de37-bfcd-4000-b033-e3513264ed24", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3fa1d0e5-a59d-4a40-ba88-87dff8acc7b7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3fa1d0e5-a59d-4a40-ba88-87dff8acc7b7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1ab7cef8-d771-4243-a2ee-850b8f22defa":{"roots":{"references":[{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"1a170b81-6dc1-44e2-b3b8-2d17cfae1a15","type":"Line"},{"attributes":{},"id":"dcbc260d-3716-403e-bc6d-5094bfd9faec","type":"BasicTicker"},{"attributes":{"plot":{"id":"5f265c67-fddd-41b8-99e3-c9f70fb87f66","subtype":"Figure","type":"Plot"}},"id":"2713bd82-a10f-4660-b8ee-cd603e587784","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"13fbc63f-fb18-4a7b-98fb-e1f94a7c21b0","type":"PanTool"},{"id":"2713bd82-a10f-4660-b8ee-cd603e587784","type":"WheelZoomTool"},{"id":"630da732-e49e-44aa-aa6c-a035d64c0df9","type":"BoxZoomTool"},{"id":"9d689291-092d-4eab-8fb9-0ce297f3ae54","type":"SaveTool"},{"id":"2e4ef4e9-fb4d-4b7e-8e89-6e17abf32564","type":"ResetTool"},{"id":"3aadea73-df26-41f3-9ec0-9cd65c7a134a","type":"HelpTool"}]},"id":"8faf43f0-18de-424f-8e35-639dd509b696","type":"Toolbar"},{"attributes":{},"id":"4b66d3f3-957d-4ca0-8133-59184186a4e0","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"38d37f69-a45b-4f16-a683-04bd4e6505d6","subtype":"Figure","type":"Plot"}},"id":"f9d523eb-a893-476c-83fe-eb1e3c9fe6e0","type":"ResetTool"},{"attributes":{"formatter":{"id":"3ca957b1-adef-4067-9e41-52d3b8941164","type":"BasicTickFormatter"},"plot":{"id":"38d37f69-a45b-4f16-a683-04bd4e6505d6","subtype":"Figure","type":"Plot"},"ticker":{"id":"8a2b321e-6117-4c9f-afe4-1332fd879bdf","type":"BasicTicker"}},"id":"1faec290-3432-4033-8987-f52a9bf8face","type":"LinearAxis"},{"attributes":{"callback":null,"end":3,"start":-3},"id":"986b4a49-3314-41c4-ad78-e17cfd3f4b2d","type":"Range1d"},{"attributes":{"below":[{"id":"90993ee5-8bb9-4060-9ba2-ebdb5502812d","type":"LinearAxis"}],"left":[{"id":"ba6a4b5e-c8d1-4ae3-a3b8-61596cf53589","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"90993ee5-8bb9-4060-9ba2-ebdb5502812d","type":"LinearAxis"},{"id":"813b84bf-be4b-49d0-bb09-ef1adc0c0666","type":"Grid"},{"id":"ba6a4b5e-c8d1-4ae3-a3b8-61596cf53589","type":"LinearAxis"},{"id":"a0a08381-90b6-40cd-9ed1-bf94ba25a85b","type":"Grid"},{"id":"d0039938-a399-4007-b04d-9cfc5e3803d8","type":"BoxAnnotation"},{"id":"87d200a0-b9d8-45c9-a9df-6a440ad69d13","type":"GlyphRenderer"}],"title":{"id":"0540adc3-c80c-49b5-9747-7828e96776c1","type":"Title"},"tool_events":{"id":"e771f2c0-46be-4e37-843f-9eb59aa64e08","type":"ToolEvents"},"toolbar":{"id":"8faf43f0-18de-424f-8e35-639dd509b696","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"581267e3-25bf-42b5-8549-5495651a37f4","type":"DataRange1d"},"y_range":{"id":"986b4a49-3314-41c4-ad78-e17cfd3f4b2d","type":"Range1d"}},"id":"5f265c67-fddd-41b8-99e3-c9f70fb87f66","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"c024d1a4-b807-445f-92c6-47f4c292a7eb","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"552680a2-8aa9-49e1-9ddf-89464f65e1f4","type":"BasicTickFormatter"},"plot":{"id":"38d37f69-a45b-4f16-a683-04bd4e6505d6","subtype":"Figure","type":"Plot"},"ticker":{"id":"0048717d-5986-47b5-a040-1a67663b1f67","type":"BasicTicker"}},"id":"26159111-4192-4746-bc90-5c49969dbd07","type":"LinearAxis"},{"attributes":{"plot":{"id":"38d37f69-a45b-4f16-a683-04bd4e6505d6","subtype":"Figure","type":"Plot"}},"id":"d2fd324d-731d-4f56-943e-95758ee9e0ca","type":"SaveTool"},{"attributes":{"formatter":{"id":"c024d1a4-b807-445f-92c6-47f4c292a7eb","type":"BasicTickFormatter"},"plot":{"id":"5f265c67-fddd-41b8-99e3-c9f70fb87f66","subtype":"Figure","type":"Plot"},"ticker":{"id":"dcbc260d-3716-403e-bc6d-5094bfd9faec","type":"BasicTicker"}},"id":"ba6a4b5e-c8d1-4ae3-a3b8-61596cf53589","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode": ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[56]</strong>&gt;</code></p>

# %%
interact(update, f=["step", "ramp", "triangle"], E=(0,3,0.05), Rs=(0.01,3,0.01), Cd=(0.01, 60, 0.1))
